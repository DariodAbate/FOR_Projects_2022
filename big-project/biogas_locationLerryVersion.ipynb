# %% [markdown]
# ## Biogas plants location
#
# An association of $n$ farmers wants to open $p$ plants to produce energy from biogas.
# Each plant will be opened at a farm of a member of the association and will be powered with corn chopping purchased from the farm itself or from other neighboring farms.
#
# Each farm $i$ can provide at most $c_i$ tons of corn chopping, with a percentage of dry matter $a_i$. As you may know, dry matter is the key component of corn chopping used for biogas production. In order to maintain the quality of produced energy, each plant must burn a mixture of corn chopping with a percentage of dry matter between $k_{min}$ and $k_{max}$.
#
# At most one plant can be located in each farm, and every farm can sell its corn chopping to one and only one plant.
#
# Each farm $i$ is located at coordinates $x_i$ and $y_i$, representing respectively its latitude and longitude, and the cost of moving corn chopping from a farm $i$ to a farm $j$ is proportional to the euclidean distance between the two farms (it does not depend on the actual quantity moved, since the trucks used for this transportations are sufficiently big).
#
# Under such conditions, every plant produces $Q$ kWh of energy per ton of corn chopping burned. The energy produced by each plant will be fed into the national electricity system, at a unitary price of $b$ (€/kWh). Moreover, due to state regulations, each plant must not produce more than $M$ kWh of energy.
#
# You must locate $p$ plants among the available farms and assign the farms that will supply each plant, with the goal of maximizing the total revenues of the association.

# %% [markdown]
# ## Mathematical model
# ### Sets
# *   $I$ = set of farms
#
# ### Parameters
# *   $n$ &nbsp; &nbsp; &nbsp; &nbsp;  number of farms
# *   $p$ &nbsp; &nbsp; &nbsp; &nbsp; number of plants to locate
# *   $c_i$ [ton] &nbsp; &nbsp; &nbsp; &nbsp; tons of corn chopping produced by farm  $i \in I$
# *   $a_i$ &nbsp; &nbsp; &nbsp; &nbsp; percentage of dry matter in chopping from farm $i \in I$
# *   $k_{max}$ &nbsp; &nbsp; &nbsp; &nbsp; max percentage of dry matter
# *   $k_{min}$ &nbsp; &nbsp; &nbsp; &nbsp; min percentage of dry matter
# *   $x_i, y_i$ &nbsp; &nbsp; &nbsp; &nbsp; coordinates of farm $i \in I$
# *   $d_{ij}$ [€] &nbsp; &nbsp; &nbsp; &nbsp; cost of moving chopping from farm $i\in I$ to farm $j\in I$
# *   $Q$ [kWh/t] &nbsp; &nbsp; &nbsp; &nbsp; energy produced by a ton of corn chopping
# *   $b$ [€/kWh] &nbsp; &nbsp; &nbsp; &nbsp; revenue per unit of energy
# *   $M$ [kWh] &nbsp; &nbsp; &nbsp; &nbsp; max energy production
#
# ### Variables
# *  $$
#     α_i = \begin{cases}
#       1 & \text{if  farm $i \in I$ has a plant installed} \\
#       0 & \text{otherwise.}
#     \end{cases}
#   $$
#
# * &nbsp; &nbsp; &nbsp; &nbsp; $β_{ij}\ge 0$ &nbsp; &nbsp; &nbsp; &nbsp; quantity of corn chopping obtained by farm $i \in I$ , from farms $j \in I$
#
# * $$
#     γ_{ij} = \begin{cases}
#       1 & \text{if }   β_{ij}>0\\
#       0 & \text{otherwise.}
#     \end{cases}
#   $$
#
# ###Objective function
# $$
# \begin{equation}
#   \max \sum_{i \in I}(bQ\sum_{j \in I}β_{ij} - \sum_{j \in I}d_{ij}γ_{ij})
# \end{equation}
# $$
#
# ###Constraints
# $$
# \begin{align*}
#        \sum_{i \in I} α_{i} = p &&&&&&&\text{open exactly p implants}\\
#        \sum_{i \in I} γ_{ij} \le 1 &&&&∀ j \in I &&&\text{each farm j can sell at most to one and only one plant}\\
#         β_{ij} \le c_{j} γ_{ij} &&&&∀ i,j \in I &&&\text{cannot get more than the quantity produced}\\
#         γ_{ij} \le α_{i} &&&&∀ i,j \in I &&&\text{can sell only to farms with plant installed}\\
#        Q\sum_{i \in I} β_{ij} \le M &&&&∀ j \in I &&&\text{cannot produce more than M kWh}\\
#        K_{min}\sum_{j \in I} β_{ij} \le \sum_{j \in I} β_{ij}a_{j} &&&&∀ i \in I &&&\text{minimum percentage of dry matter}\\
#        K_{max}\sum_{j \in I} β_{ij} \ge \sum_{j \in I} β_{ij}a_{j} &&&&∀ i \in I &&&\text{maximum percentage of dry matter}\\
# \end{align*}
# $$

# %% [markdown]
# ## Install the libraries

# %%
# Clean files if present
# !rm instance_1.json
# !rm instance_2.json
# !rm instance_3.json
# !rm instance_4.json
# !rm instance_5.json
# !rm instance_6.json
# !rm instance_7.json
# !rm instance_8.json
# !rm instance_9.json
# !rm instance_10.json

# !rm instance_1.txt
# !rm instance_2.txt
# !rm instance_3.txt
# !rm instance_4.txt
# !rm instance_5.txt
# !rm instance_6.txt
# !rm instance_7.txt
# !rm instance_8.txt
# !rm instance_9.txt
# !rm instance_10.txt

#make a folder for the analytics
# !mkdir /content/analytics


# Download instances directly from Github
# !wget https://raw.githubusercontent.com/Daddeee/FOR_Labs_22-23/master/big-project/instances/instance_1.json
# !wget https://raw.githubusercontent.com/Daddeee/FOR_Labs_22-23/master/big-project/instances/instance_2.json
# !wget https://raw.githubusercontent.com/Daddeee/FOR_Labs_22-23/master/big-project/instances/instance_3.json
# !wget https://raw.githubusercontent.com/Daddeee/FOR_Labs_22-23/master/big-project/instances/instance_4.json
# !wget https://raw.githubusercontent.com/Daddeee/FOR_Labs_22-23/master/big-project/instances/instance_5.json
# !wget https://raw.githubusercontent.com/Daddeee/FOR_Labs_22-23/master/big-project/instances/instance_6.json
# !wget https://raw.githubusercontent.com/Daddeee/FOR_Labs_22-23/master/big-project/instances/instance_7.json
# !wget https://raw.githubusercontent.com/Daddeee/FOR_Labs_22-23/master/big-project/instances/instance_8.json
# !wget https://raw.githubusercontent.com/Daddeee/FOR_Labs_22-23/master/big-project/instances/instance_9.json
# !wget https://raw.githubusercontent.com/Daddeee/FOR_Labs_22-23/master/big-project/instances/instance_10.json

# !wget https://raw.githubusercontent.com/Daddeee/FOR_Labs_22-23/master/big-project/results/instance_1.txt
# !wget https://raw.githubusercontent.com/Daddeee/FOR_Labs_22-23/master/big-project/results/instance_2.txt
# !wget https://raw.githubusercontent.com/Daddeee/FOR_Labs_22-23/master/big-project/results/instance_3.txt
# !wget https://raw.githubusercontent.com/Daddeee/FOR_Labs_22-23/master/big-project/results/instance_4.txt
# Out:
# rm: cannot remove 'instance_1.json': No such file or directory
# rm: cannot remove 'instance_2.json': No such file or directory
# rm: cannot remove 'instance_3.json': No such file or directory
# rm: cannot remove 'instance_4.json': No such file or directory
# rm: cannot remove 'instance_5.json': No such file or directory
# rm: cannot remove 'instance_6.json': No such file or directory
# rm: cannot remove 'instance_7.json': No such file or directory
# rm: cannot remove 'instance_8.json': No such file or directory
# rm: cannot remove 'instance_9.json': No such file or directory
# rm: cannot remove 'instance_10.json': No such file or directory
# rm: cannot remove 'instance_1.txt': No such file or directory
# rm: cannot remove 'instance_2.txt': No such file or directory
# rm: cannot remove 'instance_3.txt': No such file or directory
# rm: cannot remove 'instance_4.txt': No such file or directory
# rm: cannot remove 'instance_5.txt': No such file or directory
# rm: cannot remove 'instance_6.txt': No such file or directory
# rm: cannot remove 'instance_7.txt': No such file or directory
# rm: cannot remove 'instance_8.txt': No such file or directory
# rm: cannot remove 'instance_9.txt': No such file or directory
# rm: cannot remove 'instance_10.txt': No such file or directory
# --2023-01-02 21:35:09--  https://raw.githubusercontent.com/Daddeee/FOR_Labs_22-23/master/big-project/instances/instance_1.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 572 [text/plain]
# Saving to: ‘instance_1.json’
#
# instance_1.json     100%[===================>]     572  --.-KB/s    in 0s
#
# 2023-01-02 21:35:09 (19.3 MB/s) - ‘instance_1.json’ saved [572/572]
#
# --2023-01-02 21:35:09--  https://raw.githubusercontent.com/Daddeee/FOR_Labs_22-23/master/big-project/instances/instance_2.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 987 [text/plain]
# Saving to: ‘instance_2.json’
#
# instance_2.json     100%[===================>]     987  --.-KB/s    in 0s
#
# 2023-01-02 21:35:09 (46.5 MB/s) - ‘instance_2.json’ saved [987/987]
#
# --2023-01-02 21:35:09--  https://raw.githubusercontent.com/Daddeee/FOR_Labs_22-23/master/big-project/instances/instance_3.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1981 (1.9K) [text/plain]
# Saving to: ‘instance_3.json’
#
# instance_3.json     100%[===================>]   1.93K  --.-KB/s    in 0s
#
# 2023-01-02 21:35:09 (36.4 MB/s) - ‘instance_3.json’ saved [1981/1981]
#
# --2023-01-02 21:35:10--  https://raw.githubusercontent.com/Daddeee/FOR_Labs_22-23/master/big-project/instances/instance_4.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4740 (4.6K) [text/plain]
# Saving to: ‘instance_4.json’
#
# instance_4.json     100%[===================>]   4.63K  --.-KB/s    in 0s
#
# 2023-01-02 21:35:10 (54.1 MB/s) - ‘instance_4.json’ saved [4740/4740]
#
# --2023-01-02 21:35:10--  https://raw.githubusercontent.com/Daddeee/FOR_Labs_22-23/master/big-project/instances/instance_5.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6579 (6.4K) [text/plain]
# Saving to: ‘instance_5.json’
#
# instance_5.json     100%[===================>]   6.42K  --.-KB/s    in 0s
#
# 2023-01-02 21:35:10 (76.0 MB/s) - ‘instance_5.json’ saved [6579/6579]
#
# --2023-01-02 21:35:10--  https://raw.githubusercontent.com/Daddeee/FOR_Labs_22-23/master/big-project/instances/instance_6.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9370 (9.2K) [text/plain]
# Saving to: ‘instance_6.json’
#
# instance_6.json     100%[===================>]   9.15K  --.-KB/s    in 0s
#
# 2023-01-02 21:35:10 (82.5 MB/s) - ‘instance_6.json’ saved [9370/9370]
#
# --2023-01-02 21:35:10--  https://raw.githubusercontent.com/Daddeee/FOR_Labs_22-23/master/big-project/instances/instance_7.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13992 (14K) [text/plain]
# Saving to: ‘instance_7.json’
#
# instance_7.json     100%[===================>]  13.66K  --.-KB/s    in 0s
#
# 2023-01-02 21:35:10 (94.1 MB/s) - ‘instance_7.json’ saved [13992/13992]
#
# --2023-01-02 21:35:10--  https://raw.githubusercontent.com/Daddeee/FOR_Labs_22-23/master/big-project/instances/instance_8.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 18604 (18K) [text/plain]
# Saving to: ‘instance_8.json’
#
# instance_8.json     100%[===================>]  18.17K  --.-KB/s    in 0.001s
#
# 2023-01-02 21:35:10 (22.3 MB/s) - ‘instance_8.json’ saved [18604/18604]
#
# --2023-01-02 21:35:10--  https://raw.githubusercontent.com/Daddeee/FOR_Labs_22-23/master/big-project/instances/instance_9.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23213 (23K) [text/plain]
# Saving to: ‘instance_9.json’
#
# instance_9.json     100%[===================>]  22.67K  --.-KB/s    in 0.001s
#
# 2023-01-02 21:35:10 (15.6 MB/s) - ‘instance_9.json’ saved [23213/23213]
#
# --2023-01-02 21:35:10--  https://raw.githubusercontent.com/Daddeee/FOR_Labs_22-23/master/big-project/instances/instance_10.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27814 (27K) [text/plain]
# Saving to: ‘instance_10.json’
#
# instance_10.json    100%[===================>]  27.16K  --.-KB/s    in 0.001s
#
# 2023-01-02 21:35:10 (17.9 MB/s) - ‘instance_10.json’ saved [27814/27814]
#
# --2023-01-02 21:35:10--  https://raw.githubusercontent.com/Daddeee/FOR_Labs_22-23/master/big-project/results/instance_1.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 18 [text/plain]
# Saving to: ‘instance_1.txt’
#
# instance_1.txt      100%[===================>]      18  --.-KB/s    in 0s
#
# 2023-01-02 21:35:10 (972 KB/s) - ‘instance_1.txt’ saved [18/18]
#
# --2023-01-02 21:35:11--  https://raw.githubusercontent.com/Daddeee/FOR_Labs_22-23/master/big-project/results/instance_2.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 18 [text/plain]
# Saving to: ‘instance_2.txt’
#
# instance_2.txt      100%[===================>]      18  --.-KB/s    in 0s
#
# 2023-01-02 21:35:11 (729 KB/s) - ‘instance_2.txt’ saved [18/18]
#
# --2023-01-02 21:35:11--  https://raw.githubusercontent.com/Daddeee/FOR_Labs_22-23/master/big-project/results/instance_3.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 18 [text/plain]
# Saving to: ‘instance_3.txt’
#
# instance_3.txt      100%[===================>]      18  --.-KB/s    in 0s
#
# 2023-01-02 21:35:11 (762 KB/s) - ‘instance_3.txt’ saved [18/18]
#
# --2023-01-02 21:35:11--  https://raw.githubusercontent.com/Daddeee/FOR_Labs_22-23/master/big-project/results/instance_4.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17 [text/plain]
# Saving to: ‘instance_4.txt’
#
# instance_4.txt      100%[===================>]      17  --.-KB/s    in 0s
#
# 2023-01-02 21:35:11 (837 KB/s) - ‘instance_4.txt’ saved [17/17]

# %%
#installing libraries
# !pip install --upgrade cffi==1.15.0
import importlib
import cffi
importlib.reload(cffi)
# !pip install mip
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting cffi==1.15.0
#   Downloading cffi-1.15.0-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (446 kB)
#      |████████████████████████████████| 446 kB 10.6 MB/s
# Requirement already satisfied: pycparser in /usr/local/lib/python3.8/dist-packages (from cffi==1.15.0) (2.21)
# Installing collected packages: cffi
#   Attempting uninstall: cffi
#     Found existing installation: cffi 1.15.1
#     Uninstalling cffi-1.15.1:
#       Successfully uninstalled cffi-1.15.1
# Successfully installed cffi-1.15.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting mip
#   Downloading mip-1.14.2-py3-none-any.whl (15.3 MB)
#      |████████████████████████████████| 15.3 MB 7.0 MB/s
# Requirement already satisfied: cffi==1.15.0 in /usr/local/lib/python3.8/dist-packages (from mip) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.8/dist-packages (from cffi==1.15.0->mip) (2.21)
# Installing collected packages: mip
# Successfully installed mip-1.14.2

# %%
import json
import sys

# Reads a .json instance and returns it in a dictionary
def load_instance(filename):
  with open(filename, 'r') as f:
    data = json.load(f)
  return data

# Reads a .txt result and returns it
def load_result(filename):
  with open(filename, 'r') as f:
      result = f.read()
  return float(result)

# %% [markdown]
# ## Run from here

# %%
import mip
import math
from datetime import datetime

def solve(instance, k):
  I = range(inst["n"])
  M = inst["M"]
  Q = inst["Q"]
  a = inst["a"]
  b = inst["b"]
  c = inst["c"]
  kmax = inst["kmax"]
  kmin = inst["kmin"]
  p = inst["p"]

  #calculation of the distance matrix
  d = [[0 if (i == j) else math.sqrt( (inst["points"][i][0] - inst["points"][j][0])**2 + (inst["points"][i][1] - inst["points"][j][1])**2  ) for i in I] for j in I]
  
  m = mip.Model()

  #variables
  #lb (ub) = lower (upper) bound
  alpha = [m.add_var(lb=0, ub=1) for i in I]
  beta = [[m.add_var(lb=0) for i in I] for j in I] #i plant, j farm
  gamma = [[m.add_var(lb=0, ub=1) for i in I] for j in I]

  #obj func
  m.objective = mip.maximize( mip.xsum( (b * Q * beta[i][j] - d[i][j] * gamma[i][j])  for i in I for j in I) )

  #constraints
  m.add_constr( mip.xsum( alpha[i] for i in I) == p)

  for i in I:
    for j in I:
      m.add_constr( beta[i][j] <= c[j]*gamma[i][j] )
      m.add_constr(gamma[i][j] <=  alpha[i]) 
      

  for i in I:
    m.add_constr(mip.xsum( beta[i][j] * a[j] for j in I) <= kmax * mip.xsum( beta[i][j] for j in I) )
    m.add_constr(mip.xsum( beta[i][j] * a[j] for j in I) >= kmin * mip.xsum( beta[i][j] for j in I) )
    m.add_constr( Q * mip.xsum( beta[i][j] for j in I ) <= M)


  for j in I: 
    m.add_constr( mip.xsum(gamma[i][j] for i in I) <= 1)
  
  status = m.optimize()

  #generating cuts
  tot = 0
  tempvect = []
  for i in I:
      tempvect.append(alpha[i].x)
  while((inst["p"] - tot) != 0):
    tmp = tempvect.index(max(tempvect))
    m.add_constr(alpha[tmp] == 1)
    tempvect[tmp] = 0
    tot += 1
  for i in I:
    for j in I:
      gamma[i][j].var_type=mip.BINARY 
  status = m.optimize(max_seconds=60*max(1.5,inst["n"]/60))

  #printing final results
  print(status)
  print_result(m, inst, alpha, beta, gamma, k)
  return m.objective_value

# %%
#printing the analytics in /content/analytics
def print_result(m, inst, alpha, beta, gamma, k):

    import networkx as nx
    import matplotlib.pyplot as plt
    import numpy as np
    
    I = range(inst["n"])
    points = inst["points"]

    plants = [i for i in I if alpha[i].x != 0]
    farms = [i for i in I if alpha[i].x == 0]
    
    # Visualize solution on graph
    pos_farms = {f'F{i}': (points[i][0], points[i][1]) for i in farms}
    pos_plants = {f'P{i}': (points[i][0], points[i][1]) for i in plants}
    nodepos = {**pos_farms, **pos_plants}

    #print in file    
    with open('/content/analytics/GraphAnalytics' + str(k) + '.txt', 'w') as writefile:

      c=0
      for i in I:
        c= c + alpha[i].x
      writefile.write("Number of plants installed / Number of plants requested: " + str(c) + " / " + str(inst["p"]) + "\n")

      writefile.write("\nALPHA" + "\n")
      for i in I:
        writefile.write(str(i) + ": " + str(alpha[i].x) + "\n")

      writefile.write("\nBETA" + "\n")
      for i in I:
        for j in I:
          writefile.write(str(round(beta[i][j].x, 3)) + "\t\t\t\t")
        writefile.write("\n")
      
      writefile.write("\nGAMMA" + "\n")
      for i in I:
        for j in I:
          writefile.write(str(round(gamma[i][j].x, 3)) + "\t\t\t\t")
        writefile.write("\n")

      writefile.write("\nCOORDINATES" + "\n")
      for i in nodepos.keys():
        writefile.write(str(i) + ": " + str(nodepos.get(str(i))) + "\n")

    g = nx.Graph()
    g.add_nodes_from([f'F{i}' for i in farms])
    g.add_nodes_from([f'P{i}' for i in plants])
    edges = [(f'F{j}', f'P{i}') for j in farms for i in plants if beta[i][j].x > 0] 
    g.add_edges_from(edges)
    edges2 = [(f'P{j}', f'P{i}') for j in plants for i in plants if beta[i][j].x > 0]
    g.add_edges_from(edges2)
    color = ['yellow']*(len(farms)) + ['cyan']*(len(plants))
    plt.figure(1, figsize=(14,14))
    nx.draw_networkx(g, font_size=11, pos=nodepos, node_color=color)
    plt.show()
    plt.close

# %%
#solve the problem
for k in range(1,11):

  #print in a file the analytics
  with open('/content/analytics/Instance' + str(k) + '.txt', 'w') as writefile:
    print("INSTANCE #" + str(k))
    writefile.write("INSTANCE #" + str(k) + "\n")
    startTime = datetime.now()
    writefile.write("start time: " + str(startTime) + "\n")

    inst = load_instance("instance_" + str(k) + ".json")
    obj = solve(inst, k)

    endTime = datetime.now()
    writefile.write("end time: " + str(endTime) + "\n")
    writefile.write("time of computation: " + str(endTime-startTime) + "\n")

    writefile.write("result" + " : {}".format(obj) + "\n")

    if(k in {1, 2, 3, 4}):
      res = load_result("instance_" + str(k) + ".txt")
      gap = 100 * (obj - res) / res

      writefile.write("expected" + " : {}".format(res) + "\n")
      writefile.write("gap" + " : {}".format(gap) + "\n")
# Out:
# INSTANCE #1
# OptimizationStatus.OPTIMAL
# INSTANCE #2
# OptimizationStatus.OPTIMAL
# INSTANCE #3
